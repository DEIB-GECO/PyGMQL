# %% [markdown]
# ## Index
#
# 0. [Introduction](./00_Introduction.ipynb)
# 1. [A simple example](./01_A_simple_example.ipynb)
# 2. [Mixing Local and Remote processing](./02_Mixing_Local_Remote_Processing.ipynb)
# 3. [GWAS on cloud](./03_GWAS.ipynb)

# %% [markdown]
# # Chapter 1: *A simple example*
#
# In this first tutorial we will show a complete example of usage of the library using some example datasets provided with it.

# %% [markdown]
# ## Importing the library

# %% [markdown]
# #### Setting the JAVA_HOME environment variable (necessary only inside myBinder)
# The following instructions are only necessary in this tutorials when they are run using the myBinder interface!

# %%
import os
os.environ['JAVA_HOME'] = '/usr/'

# %% [markdown]
# #### Importing the library

# %%
import gmql as gl

# %% [markdown]
# ## Loading datasets
#
# PyGMQL can work with BED and GTF files with arbitrary fields and schemas. In order to load a dataset into Python the user can use the following functions:
#
# - `load_from_path`: lazily loads a dataset into a GMQLDataset variable from the local file system
# - `load_from_remote`: lazily loads a dataset into a GMQLDataset variable from a remote GMQL service
# - `from_pandas`: lazily loads a dataset into a GMQLDataset variable from a Pandas DataFrame having at least the chromosome, start and stop columns
#
# In addition to these functions we also provide a function called `get_example_dataset` which enables the user to load a sample dataset and play with it in order to get confidence with the library. Currently we provide two example datasets: `Example_Dataset_1` and `Example_Dataset_2`.
#
# In the following we will load two example datasets and play with them.

# %%
dataset1 = gl.get_example_dataset("Example_Dataset_1")
dataset2 = gl.get_example_dataset("Example_Dataset_2")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:01<00:00,  5.04it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:01<00:00,  4.19it/s]

# %% [markdown]
# ## The `GMQLDataset`
# The `dataset` variable defined above is a `GMQLDataset`, which represents a GMQL variable and on which it is possible to apply GMQL operators. It must be noticed that no data has been loaded in memory yet and the computation will only start when the query is triggered. We will see how to start the execution of a query in the following steps.
#
# We can inspect the schema of the dataset with the following:

# %%
dataset1.schema
# Out:
# ['source',
#  'feature',
#  'score',
#  'frame',
#  'name',
#  'signal',
#  'pvalue',
#  'qvalue',
#  'peak',
#  'chr',
#  'start',
#  'stop',
#  'strand']

# %%
dataset2.schema
# Out:
# ['source',
#  'feature',
#  'score',
#  'frame',
#  'name',
#  'signal',
#  'pvalue',
#  'qvalue',
#  'peak',
#  'chr',
#  'start',
#  'stop',
#  'strand']

# %% [markdown]
# ## Filtering the dataset regions based on a predicate
#
# The first operation we will do on `dataset` will be selecting only the genomic regions on the 3rd chromosome and with a start position greater than 30000.

# %%
filtered_dataset1 = dataset1.reg_select((dataset1.chr == 'chr3') & (dataset1.start >= 30000))

# %% [markdown]
# From this operation we can learn several things about the `GMQLDataset` data structure. Each `GMQLDataset` has a set of methods and fields which can be used to build GMQL queries. For example, in the previous statement we have:
# - the `reg_select` method, which enables us to filter the datasets on the basis of a predicate on the region positions and features
# - the `chr` and `start` fields, which enable the user to build predicates on the fields of the dataset.
#
# Every GMQL operator has a relative method accessible from the `GMQLDataset` data structure, as well as any other field of the dataset.

# %% [markdown]
# ## Filtering a dataset based on a predicate on metadata
#
# The Genomic Data Model enables us to work both with genomic regions and their relative metadata. Therefore we can filter dataset samples on the basis of predicates on metadata attributes. This can be done as follows:

# %%
filtered_dataset_2 = dataset2[dataset2['antibody_target'] == 'CTCF']

# %% [markdown]
# Notice that the notation for selecting the samples using metadata is the same as the one for filtering Pandas DataFrames.

# %% [markdown]
# ## Joining two datasets
#
# It is not the focus of this tutorial to show all the possible operations which can be done on a `GMQLDataset`, they can be seen on the documentation page of the library.
#
# For the sake of this example, let's show the JOIN operation between the two filtered datasets defined in the previous two steps.
# The JOIN operation semantics relies on the concept of *reference* and *experiment* datasets. The reference dataset is the one 'calling' the join function while the experiment dataset is the one 'on which' the function is called. The semantics of the function is
#
# ```
# resulting_dataset = <reference>.join(<experiment>, <genometric predicate>, ...)
# ```

# %%
dataset_join = dataset1.join(dataset2, [gl.DLE(0)])

# %% [markdown]
# To understand the concept of *genometric predicate* please visit the documentation of the library.

# %% [markdown]
# ## Materialization of the results
#
# As we have already said, no operation has beed effectively done up to this point. What we did up to now is to define the sequence of operations to apply on the data. In order to trigger the execution we have to apply the `materialize` function on the variable we want to compute.

# %%
query_result = dataset_join.materialize()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 12020.93it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 190/190 [00:01<00:00, 166.55it/s]

# %% [markdown]
# ## The `GDataframe`
#
# The `query_result` variable holds the result of the previous GMQL query in the form of a `GDataframe` data structure. It holds the information about the regions and the metadata of the result, which can be respectively accessed through the `regs` and `meta` attributes.
#
# <img src="../doc/source/images/architecture_GDataframe.png" width="600">

# %% [markdown]
# ### Regions

# %%
query_result.regs
# Out:
#                        chr  start  stop strand REF.source REF.feature  \
# id_sample
#  4356738178105158401  chr2    399   440      *       GMQL      Region
#  4670800706188226503  chr2    399   440      *       GMQL      Region
#  4356738178105158401  chr2    539   570      *       GMQL      Region
#  4670800706188226503  chr2    199   240      *       GMQL      Region
# -7728122121608963789  chr2    199   240      *       GMQL      Region
#  4670800706188226503  chr2     99   150      *       GMQL      Region
# -7728122121608963789  chr2     99   150      *       GMQL      Region
#  4670800706188226503  chr5    299   340      +       GMQL      Region
#  4670800706188226503  chr5     99   200      *       GMQL      Region
#  4670800706188226503  chr5    379   420      -       GMQL      Region
#  5758100849671408287  chr4    199   249      -       GMQL      Region
#  5758100849671408287  chr4    149   179      -       GMQL      Region
#
#                       REF.score REF.frame REF.name  REF.signal    ...     \
# id_sample                                                         ...
#  4356738178105158401        0.9         .        .        15.0    ...
#  4670800706188226503        0.9         .        .        15.0    ...
#  4356738178105158401        0.9         .        .        15.0    ...
#  4670800706188226503        9.0         .        .        22.0    ...
# -7728122121608963789        9.0         .        .        22.0    ...
#  4670800706188226503       10.0         .        .         9.0    ...
# -7728122121608963789       10.0         .        .         9.0    ...
#  4670800706188226503        4.0         .        .        15.0    ...
#  4670800706188226503        4.0         .        .        15.0    ...
#  4670800706188226503        3.0         .        .        15.0    ...
#  5758100849671408287        0.9         .        .        15.0    ...
#  5758100849671408287        0.9         .        .        15.0    ...
#
#                       REF.peak  EXP.source  EXP.feature EXP.score EXP.frame  \
# id_sample
#  4356738178105158401      -1.0        GMQL       Region       5.0         .
#  4670800706188226503      -1.0        GMQL       Region       5.0         .
#  4356738178105158401      -1.0        GMQL       Region       0.8         .
#  4670800706188226503      -1.0        GMQL       Region       7.0         .
# -7728122121608963789      -1.0        GMQL       Region      12.0         .
#  4670800706188226503      -1.0        GMQL       Region       5.0         .
# -7728122121608963789      -1.0        GMQL       Region      12.0         .
#  4670800706188226503      -1.0        GMQL       Region       7.0         .
#  4670800706188226503      -1.0        GMQL       Region       7.0         .
#  4670800706188226503      -1.0        GMQL       Region       3.0         .
#  5758100849671408287      -1.0        GMQL       Region     240.0         .
#  5758100849671408287      -1.0        GMQL       Region     240.0         .
#
#                        EXP.name EXP.signal EXP.pvalue  EXP.qvalue  EXP.peak
# id_sample
#  4356738178105158401          .     9.0000   10.83870        -1.0      -1.0
#  4670800706188226503  chr2.2540     0.0469    1.80000        -1.0     138.0
#  4356738178105158401          .     9.0000    4.65281        -1.0      -1.0
#  4670800706188226503  chr2.2539     0.0401    1.56000        -1.0     113.0
# -7728122121608963789          .    20.0000   -1.00000        -1.0      -1.0
#  4670800706188226503  chr2.2538     0.0332    1.30000        -1.0      32.0
# -7728122121608963789          .    20.0000   -1.00000        -1.0      -1.0
#  4670800706188226503  chr2.2541     0.0561    2.14000        -1.0     175.0
#  4670800706188226503  chr2.2540     0.0469    1.80000        -1.0     138.0
#  4670800706188226503  chr2.2542     0.0393    1.53000        -1.0     226.0
#  5758100849671408287          .    17.0000   11.16750        -1.0      -1.0
#  5758100849671408287          .    17.0000   11.16750        -1.0      -1.0
#
# [12 rows x 22 columns]

# %% [markdown]
# ### Metadata

# %%
query_result.meta
# Out:
#                       EXP.ID EXP.antibody  \
# id_sample
# -8999039739831780787  [1891]       [CTCF]
# -8744938632702845394  [1460]           []
# -8566469212180078812  [1892]       [CTCF]
# -7728122121608963789    [42]           []
# -7571531587018517458  [1892]       [CTCF]
# -7274403533498165236  [1460]           []
# -7174482946763632851  [1891]       [CTCF]
# -6107064225402621984  [1892]       [CTCF]
# -5613686959981835932  [1892]       [CTCF]
# -5547787815266160171   [870]           []
# -5206559097245982026    [42]           []
# -4809357744822545570  [1460]           []
# -4545122299167928641   [870]           []
# -4334024508598276599  [1459]           []
# -4003985073582185229    [42]           []
# -2288717307818523231  [1891]       [CTCF]
# -1779729825897418860  [1460]           []
# -1720945943358774381   [870]           []
# -1506301473018871417  [1460]           []
# -1295451930882459714  [1892]       [CTCF]
# -1077951584315524970   [870]           []
# -289722276641965584   [1460]           []
#  357847681334138771   [1892]       [CTCF]
#  535566393954238245   [1459]           []
#  580396054200165625    [870]           []
#  734345270105822253   [1459]           []
#  2567134621152254196  [1460]           []
#  4056522925901197444  [1891]       [CTCF]
#  4356738178105158401  [1892]       [CTCF]
#  4670800706188226503   [870]           []
#  4699890671745240445    [42]           []
#  5231107346087398290   [870]           []
#  5279940861434921501  [1459]           []
#  5758100849671408287  [1891]       [CTCF]
#  6405958935940856108  [1891]       [CTCF]
#  6494839943794824182    [42]           []
#  7022198604924335400  [1891]       [CTCF]
#  7775072887239173135  [1459]           []
#  8125819659820370243    [42]           []
#  8133547364044521244  [1459]           []
#  8379254714722134375  [1459]           []
#  9208210556105108342    [42]           []
#
#                                 EXP.antibody_antibodyDescription  \
# id_sample
# -8999039739831780787  [Rabbit polyclonal. Antibody Target: CTCF]
# -8744938632702845394                                          []
# -8566469212180078812  [Rabbit polyclonal. Antibody Target: CTCF]
# -7728122121608963789                                          []
# -7571531587018517458  [Rabbit polyclonal. Antibody Target: CTCF]
# -7274403533498165236                                          []
# -7174482946763632851  [Rabbit polyclonal. Antibody Target: CTCF]
# -6107064225402621984  [Rabbit polyclonal. Antibody Target: CTCF]
# -5613686959981835932  [Rabbit polyclonal. Antibody Target: CTCF]
# -5547787815266160171                                          []
# -5206559097245982026                                          []
# -4809357744822545570                                          []
# -4545122299167928641                                          []
# -4334024508598276599                                          []
# -4003985073582185229                                          []
# -2288717307818523231  [Rabbit polyclonal. Antibody Target: CTCF]
# -1779729825897418860                                          []
# -1720945943358774381                                          []
# -1506301473018871417                                          []
# -1295451930882459714  [Rabbit polyclonal. Antibody Target: CTCF]
# -1077951584315524970                                          []
# -289722276641965584                                           []
#  357847681334138771   [Rabbit polyclonal. Antibody Target: CTCF]
#  535566393954238245                                           []
#  580396054200165625                                           []
#  734345270105822253                                           []
#  2567134621152254196                                          []
#  4056522925901197444  [Rabbit polyclonal. Antibody Target: CTCF]
#  4356738178105158401  [Rabbit polyclonal. Antibody Target: CTCF]
#  4670800706188226503                                          []
#  4699890671745240445                                          []
#  5231107346087398290                                          []
#  5279940861434921501                                          []
#  5758100849671408287  [Rabbit polyclonal. Antibody Target: CTCF]
#  6405958935940856108  [Rabbit polyclonal. Antibody Target: CTCF]
#  6494839943794824182                                          []
#  7022198604924335400  [Rabbit polyclonal. Antibody Target: CTCF]
#  7775072887239173135                                          []
#  8125819659820370243                                          []
#  8133547364044521244                                          []
#  8379254714722134375                                          []
#  9208210556105108342                                          []
#
#                                EXP.antibody_lab EXP.antibody_label  \
# id_sample
# -8999039739831780787  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -8744938632702845394                         []                 []
# -8566469212180078812  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -7728122121608963789                         []                 []
# -7571531587018517458  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -7274403533498165236                         []                 []
# -7174482946763632851  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -6107064225402621984  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -5613686959981835932  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -5547787815266160171                         []                 []
# -5206559097245982026                         []                 []
# -4809357744822545570                         []                 []
# -4545122299167928641                         []                 []
# -4334024508598276599                         []                 []
# -4003985073582185229                         []                 []
# -2288717307818523231  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -1779729825897418860                         []                 []
# -1720945943358774381                         []                 []
# -1506301473018871417                         []                 []
# -1295451930882459714  [Myers, Hardison, Snyder]    [CTCF (07-729)]
# -1077951584315524970                         []                 []
# -289722276641965584                          []                 []
#  357847681334138771   [Myers, Hardison, Snyder]    [CTCF (07-729)]
#  535566393954238245                          []                 []
#  580396054200165625                          []                 []
#  734345270105822253                          []                 []
#  2567134621152254196                         []                 []
#  4056522925901197444  [Myers, Hardison, Snyder]    [CTCF (07-729)]
#  4356738178105158401  [Myers, Hardison, Snyder]    [CTCF (07-729)]
#  4670800706188226503                         []                 []
#  4699890671745240445                         []                 []
#  5231107346087398290                         []                 []
#  5279940861434921501                         []                 []
#  5758100849671408287  [Myers, Hardison, Snyder]    [CTCF (07-729)]
#  6405958935940856108  [Myers, Hardison, Snyder]    [CTCF (07-729)]
#  6494839943794824182                         []                 []
#  7022198604924335400  [Myers, Hardison, Snyder]    [CTCF (07-729)]
#  7775072887239173135                         []                 []
#  8125819659820370243                         []                 []
#  8133547364044521244                         []                 []
#  8379254714722134375                         []                 []
#  9208210556105108342                         []                 []
#
#                          EXP.antibody_lots  \
# id_sample
# -8999039739831780787  [1350637 DAM1472197]
# -8744938632702845394                    []
# -8566469212180078812  [1350637 DAM1472197]
# -7728122121608963789                    []
# -7571531587018517458  [1350637 DAM1472197]
# -7274403533498165236                    []
# -7174482946763632851  [1350637 DAM1472197]
# -6107064225402621984  [1350637 DAM1472197]
# -5613686959981835932  [1350637 DAM1472197]
# -5547787815266160171                    []
# -5206559097245982026                    []
# -4809357744822545570                    []
# -4545122299167928641                    []
# -4334024508598276599                    []
# -4003985073582185229                    []
# -2288717307818523231  [1350637 DAM1472197]
# -1779729825897418860                    []
# -1720945943358774381                    []
# -1506301473018871417                    []
# -1295451930882459714  [1350637 DAM1472197]
# -1077951584315524970                    []
# -289722276641965584                     []
#  357847681334138771   [1350637 DAM1472197]
#  535566393954238245                     []
#  580396054200165625                     []
#  734345270105822253                     []
#  2567134621152254196                    []
#  4056522925901197444  [1350637 DAM1472197]
#  4356738178105158401  [1350637 DAM1472197]
#  4670800706188226503                    []
#  4699890671745240445                    []
#  5231107346087398290                    []
#  5279940861434921501                    []
#  5758100849671408287  [1350637 DAM1472197]
#  6405958935940856108  [1350637 DAM1472197]
#  6494839943794824182                    []
#  7022198604924335400  [1350637 DAM1472197]
#  7775072887239173135                    []
#  8125819659820370243                    []
#  8133547364044521244                    []
#  8379254714722134375                    []
#  9208210556105108342                    []
#
#                                                  EXP.antibody_orderUrl  \
# id_sample
# -8999039739831780787  [http://www.millipore.com/catalogue/item/07-729]
# -8744938632702845394                                                []
# -8566469212180078812  [http://www.millipore.com/catalogue/item/07-729]
# -7728122121608963789                                                []
# -7571531587018517458  [http://www.millipore.com/catalogue/item/07-729]
# -7274403533498165236                                                []
# -7174482946763632851  [http://www.millipore.com/catalogue/item/07-729]
# -6107064225402621984  [http://www.millipore.com/catalogue/item/07-729]
# -5613686959981835932  [http://www.millipore.com/catalogue/item/07-729]
# -5547787815266160171                                                []
# -5206559097245982026                                                []
# -4809357744822545570                                                []
# -4545122299167928641                                                []
# -4334024508598276599                                                []
# -4003985073582185229                                                []
# -2288717307818523231  [http://www.millipore.com/catalogue/item/07-729]
# -1779729825897418860                                                []
# -1720945943358774381                                                []
# -1506301473018871417                                                []
# -1295451930882459714  [http://www.millipore.com/catalogue/item/07-729]
# -1077951584315524970                                                []
# -289722276641965584                                                 []
#  357847681334138771   [http://www.millipore.com/catalogue/item/07-729]
#  535566393954238245                                                 []
#  580396054200165625                                                 []
#  734345270105822253                                                 []
#  2567134621152254196                                                []
#  4056522925901197444  [http://www.millipore.com/catalogue/item/07-729]
#  4356738178105158401  [http://www.millipore.com/catalogue/item/07-729]
#  4670800706188226503                                                []
#  4699890671745240445                                                []
#  5231107346087398290                                                []
#  5279940861434921501                                                []
#  5758100849671408287  [http://www.millipore.com/catalogue/item/07-729]
#  6405958935940856108  [http://www.millipore.com/catalogue/item/07-729]
#  6494839943794824182                                                []
#  7022198604924335400  [http://www.millipore.com/catalogue/item/07-729]
#  7775072887239173135                                                []
#  8125819659820370243                                                []
#  8133547364044521244                                                []
#  8379254714722134375                                                []
#  9208210556105108342                                                []
#
#                      EXP.antibody_tag EXP.antibody_target  \
# id_sample
# -8999039739831780787           [CTCF]              [CTCF]
# -8744938632702845394               []                  []
# -8566469212180078812           [CTCF]              [CTCF]
# -7728122121608963789               []                  []
# -7571531587018517458           [CTCF]              [CTCF]
# -7274403533498165236               []                  []
# -7174482946763632851           [CTCF]              [CTCF]
# -6107064225402621984           [CTCF]              [CTCF]
# -5613686959981835932           [CTCF]              [CTCF]
# -5547787815266160171               []                  []
# -5206559097245982026               []                  []
# -4809357744822545570               []                  []
# -4545122299167928641               []                  []
# -4334024508598276599               []                  []
# -4003985073582185229               []                  []
# -2288717307818523231           [CTCF]              [CTCF]
# -1779729825897418860               []                  []
# -1720945943358774381               []                  []
# -1506301473018871417               []                  []
# -1295451930882459714           [CTCF]              [CTCF]
# -1077951584315524970               []                  []
# -289722276641965584                []                  []
#  357847681334138771            [CTCF]              [CTCF]
#  535566393954238245                []                  []
#  580396054200165625                []                  []
#  734345270105822253                []                  []
#  2567134621152254196               []                  []
#  4056522925901197444           [CTCF]              [CTCF]
#  4356738178105158401           [CTCF]              [CTCF]
#  4670800706188226503               []                  []
#  4699890671745240445               []                  []
#  5231107346087398290               []                  []
#  5279940861434921501               []                  []
#  5758100849671408287           [CTCF]              [CTCF]
#  6405958935940856108           [CTCF]              [CTCF]
#  6494839943794824182               []                  []
#  7022198604924335400           [CTCF]              [CTCF]
#  7775072887239173135               []                  []
#  8125819659820370243               []                  []
#  8133547364044521244               []                  []
#  8379254714722134375               []                  []
#  9208210556105108342               []                  []
#
#                      EXP.antibody_targetClass      ...       \
# id_sample                                          ...
# -8999039739831780787                   [TFSS]      ...
# -8744938632702845394                       []      ...
# -8566469212180078812                   [TFSS]      ...
# -7728122121608963789                       []      ...
# -7571531587018517458                   [TFSS]      ...
# -7274403533498165236                       []      ...
# -7174482946763632851                   [TFSS]      ...
# -6107064225402621984                   [TFSS]      ...
# -5613686959981835932                   [TFSS]      ...
# -5547787815266160171                       []      ...
# -5206559097245982026                       []      ...
# -4809357744822545570                       []      ...
# -4545122299167928641                       []      ...
# -4334024508598276599                       []      ...
# -4003985073582185229                       []      ...
# -2288717307818523231                   [TFSS]      ...
# -1779729825897418860                       []      ...
# -1720945943358774381                       []      ...
# -1506301473018871417                       []      ...
# -1295451930882459714                   [TFSS]      ...
# -1077951584315524970                       []      ...
# -289722276641965584                        []      ...
#  357847681334138771                    [TFSS]      ...
#  535566393954238245                        []      ...
#  580396054200165625                        []      ...
#  734345270105822253                        []      ...
#  2567134621152254196                       []      ...
#  4056522925901197444                   [TFSS]      ...
#  4356738178105158401                   [TFSS]      ...
#  4670800706188226503                       []      ...
#  4699890671745240445                       []      ...
#  5231107346087398290                       []      ...
#  5279940861434921501                       []      ...
#  5758100849671408287                   [TFSS]      ...
#  6405958935940856108                   [TFSS]      ...
#  6494839943794824182                       []      ...
#  7022198604924335400                   [TFSS]      ...
#  7775072887239173135                       []      ...
#  8125819659820370243                       []      ...
#  8133547364044521244                       []      ...
#  8379254714722134375                       []      ...
#  9208210556105108342                       []      ...
#
#                          REF.treatment_label REF.treatment_tag  \
# id_sample
# -8999039739831780787  [No treatment or prot]            [NONE]
# -8744938632702845394  [No treatment or prot]            [NONE]
# -8566469212180078812  [No treatment or prot]            [NONE]
# -7728122121608963789  [No treatment or prot]            [NONE]
# -7571531587018517458  [No treatment or prot]            [NONE]
# -7274403533498165236  [No treatment or prot]            [NONE]
# -7174482946763632851  [No treatment or prot]            [NONE]
# -6107064225402621984  [No treatment or prot]            [NONE]
# -5613686959981835932  [No treatment or prot]            [NONE]
# -5547787815266160171  [No treatment or prot]            [NONE]
# -5206559097245982026  [No treatment or prot]            [NONE]
# -4809357744822545570  [No treatment or prot]            [NONE]
# -4545122299167928641  [No treatment or prot]            [NONE]
# -4334024508598276599  [No treatment or prot]            [NONE]
# -4003985073582185229  [No treatment or prot]            [NONE]
# -2288717307818523231  [No treatment or prot]            [NONE]
# -1779729825897418860  [No treatment or prot]            [NONE]
# -1720945943358774381  [No treatment or prot]            [NONE]
# -1506301473018871417  [No treatment or prot]            [NONE]
# -1295451930882459714  [No treatment or prot]            [NONE]
# -1077951584315524970  [No treatment or prot]            [NONE]
# -289722276641965584   [No treatment or prot]            [NONE]
#  357847681334138771   [No treatment or prot]            [NONE]
#  535566393954238245   [No treatment or prot]            [NONE]
#  580396054200165625   [No treatment or prot]            [NONE]
#  734345270105822253   [No treatment or prot]            [NONE]
#  2567134621152254196  [No treatment or prot]            [NONE]
#  4056522925901197444  [No treatment or prot]            [NONE]
#  4356738178105158401  [No treatment or prot]            [NONE]
#  4670800706188226503  [No treatment or prot]            [NONE]
#  4699890671745240445  [No treatment or prot]            [NONE]
#  5231107346087398290  [No treatment or prot]            [NONE]
#  5279940861434921501  [No treatment or prot]            [NONE]
#  5758100849671408287  [No treatment or prot]            [NONE]
#  6405958935940856108  [No treatment or prot]            [NONE]
#  6494839943794824182  [No treatment or prot]            [NONE]
#  7022198604924335400  [No treatment or prot]            [NONE]
#  7775072887239173135  [No treatment or prot]            [NONE]
#  8125819659820370243  [No treatment or prot]            [NONE]
#  8133547364044521244  [No treatment or prot]            [NONE]
#  8379254714722134375  [No treatment or prot]            [NONE]
#  9208210556105108342  [No treatment or prot]            [NONE]
#
#                      REF.treatment_type      REF.type  \
# id_sample
# -8999039739831780787          [control]  [narrowPeak]
# -8744938632702845394          [control]  [narrowPeak]
# -8566469212180078812          [control]  [narrowPeak]
# -7728122121608963789          [control]  [narrowPeak]
# -7571531587018517458          [control]  [narrowPeak]
# -7274403533498165236          [control]  [narrowPeak]
# -7174482946763632851          [control]  [narrowPeak]
# -6107064225402621984          [control]  [narrowPeak]
# -5613686959981835932          [control]  [narrowPeak]
# -5547787815266160171          [control]  [narrowPeak]
# -5206559097245982026          [control]  [narrowPeak]
# -4809357744822545570          [control]  [narrowPeak]
# -4545122299167928641          [control]  [narrowPeak]
# -4334024508598276599          [control]  [narrowPeak]
# -4003985073582185229          [control]  [narrowPeak]
# -2288717307818523231          [control]  [narrowPeak]
# -1779729825897418860          [control]  [narrowPeak]
# -1720945943358774381          [control]  [narrowPeak]
# -1506301473018871417          [control]  [narrowPeak]
# -1295451930882459714          [control]  [narrowPeak]
# -1077951584315524970          [control]  [narrowPeak]
# -289722276641965584           [control]  [narrowPeak]
#  357847681334138771           [control]  [narrowPeak]
#  535566393954238245           [control]  [narrowPeak]
#  580396054200165625           [control]  [narrowPeak]
#  734345270105822253           [control]  [narrowPeak]
#  2567134621152254196          [control]  [narrowPeak]
#  4056522925901197444          [control]  [narrowPeak]
#  4356738178105158401          [control]  [narrowPeak]
#  4670800706188226503          [control]  [narrowPeak]
#  4699890671745240445          [control]  [narrowPeak]
#  5231107346087398290          [control]  [narrowPeak]
#  5279940861434921501          [control]  [narrowPeak]
#  5758100849671408287          [control]  [narrowPeak]
#  6405958935940856108          [control]  [narrowPeak]
#  6494839943794824182          [control]  [narrowPeak]
#  7022198604924335400          [control]  [narrowPeak]
#  7775072887239173135          [control]  [narrowPeak]
#  8125819659820370243          [control]  [narrowPeak]
#  8133547364044521244          [control]  [narrowPeak]
#  8379254714722134375          [control]  [narrowPeak]
#  9208210556105108342          [control]  [narrowPeak]
#
#                                                                 REF.url  \
# id_sample
# -8999039739831780787  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -8744938632702845394  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -8566469212180078812  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -7728122121608963789  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -7571531587018517458  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -7274403533498165236  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -7174482946763632851  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -6107064225402621984  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -5613686959981835932  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -5547787815266160171  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -5206559097245982026  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -4809357744822545570  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -4545122299167928641  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -4334024508598276599  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -4003985073582185229  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -2288717307818523231  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -1779729825897418860  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -1720945943358774381  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -1506301473018871417  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -1295451930882459714  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -1077951584315524970  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
# -289722276641965584   [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  357847681334138771   [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  535566393954238245   [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  580396054200165625   [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  734345270105822253   [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  2567134621152254196  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  4056522925901197444  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  4356738178105158401  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  4670800706188226503  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  4699890671745240445  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  5231107346087398290  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  5279940861434921501  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  5758100849671408287  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  6405958935940856108  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  6494839943794824182  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  7022198604924335400  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  7775072887239173135  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  8125819659820370243  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  8133547364044521244  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  8379254714722134375  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#  9208210556105108342  [http://hgdownload.cse.ucsc.edu/goldenPath/hg1...
#
#                      REF.view                        REF.view_description  \
# id_sample
# -8999039739831780787  [Peaks]  [Regions of enriched signal in experiment]
# -8744938632702845394  [Peaks]  [Regions of enriched signal in experiment]
# -8566469212180078812  [Peaks]  [Regions of enriched signal in experiment]
# -7728122121608963789  [Peaks]  [Regions of enriched signal in experiment]
# -7571531587018517458  [Peaks]  [Regions of enriched signal in experiment]
# -7274403533498165236  [Peaks]  [Regions of enriched signal in experiment]
# -7174482946763632851  [Peaks]  [Regions of enriched signal in experiment]
# -6107064225402621984  [Peaks]  [Regions of enriched signal in experiment]
# -5613686959981835932  [Peaks]  [Regions of enriched signal in experiment]
# -5547787815266160171  [Peaks]  [Regions of enriched signal in experiment]
# -5206559097245982026  [Peaks]  [Regions of enriched signal in experiment]
# -4809357744822545570  [Peaks]  [Regions of enriched signal in experiment]
# -4545122299167928641  [Peaks]  [Regions of enriched signal in experiment]
# -4334024508598276599  [Peaks]  [Regions of enriched signal in experiment]
# -4003985073582185229  [Peaks]  [Regions of enriched signal in experiment]
# -2288717307818523231  [Peaks]  [Regions of enriched signal in experiment]
# -1779729825897418860  [Peaks]  [Regions of enriched signal in experiment]
# -1720945943358774381  [Peaks]  [Regions of enriched signal in experiment]
# -1506301473018871417  [Peaks]  [Regions of enriched signal in experiment]
# -1295451930882459714  [Peaks]  [Regions of enriched signal in experiment]
# -1077951584315524970  [Peaks]  [Regions of enriched signal in experiment]
# -289722276641965584   [Peaks]  [Regions of enriched signal in experiment]
#  357847681334138771   [Peaks]  [Regions of enriched signal in experiment]
#  535566393954238245   [Peaks]  [Regions of enriched signal in experiment]
#  580396054200165625   [Peaks]  [Regions of enriched signal in experiment]
#  734345270105822253   [Peaks]  [Regions of enriched signal in experiment]
#  2567134621152254196  [Peaks]  [Regions of enriched signal in experiment]
#  4056522925901197444  [Peaks]  [Regions of enriched signal in experiment]
#  4356738178105158401  [Peaks]  [Regions of enriched signal in experiment]
#  4670800706188226503  [Peaks]  [Regions of enriched signal in experiment]
#  4699890671745240445  [Peaks]  [Regions of enriched signal in experiment]
#  5231107346087398290  [Peaks]  [Regions of enriched signal in experiment]
#  5279940861434921501  [Peaks]  [Regions of enriched signal in experiment]
#  5758100849671408287  [Peaks]  [Regions of enriched signal in experiment]
#  6405958935940856108  [Peaks]  [Regions of enriched signal in experiment]
#  6494839943794824182  [Peaks]  [Regions of enriched signal in experiment]
#  7022198604924335400  [Peaks]  [Regions of enriched signal in experiment]
#  7775072887239173135  [Peaks]  [Regions of enriched signal in experiment]
#  8125819659820370243  [Peaks]  [Regions of enriched signal in experiment]
#  8133547364044521244  [Peaks]  [Regions of enriched signal in experiment]
#  8379254714722134375  [Peaks]  [Regions of enriched signal in experiment]
#  9208210556105108342  [Peaks]  [Regions of enriched signal in experiment]
#
#                      REF.view_label REF.view_tag REF.view_type
# id_sample
# -8999039739831780787        [Peaks]        [PKS]        [view]
# -8744938632702845394        [Peaks]        [PKS]        [view]
# -8566469212180078812        [Peaks]        [PKS]        [view]
# -7728122121608963789        [Peaks]        [PKS]        [view]
# -7571531587018517458        [Peaks]        [PKS]        [view]
# -7274403533498165236        [Peaks]        [PKS]        [view]
# -7174482946763632851        [Peaks]        [PKS]        [view]
# -6107064225402621984        [Peaks]        [PKS]        [view]
# -5613686959981835932        [Peaks]        [PKS]        [view]
# -5547787815266160171        [Peaks]        [PKS]        [view]
# -5206559097245982026        [Peaks]        [PKS]        [view]
# -4809357744822545570        [Peaks]        [PKS]        [view]
# -4545122299167928641        [Peaks]        [PKS]        [view]
# -4334024508598276599        [Peaks]        [PKS]        [view]
# -4003985073582185229        [Peaks]        [PKS]        [view]
# -2288717307818523231        [Peaks]        [PKS]        [view]
# -1779729825897418860        [Peaks]        [PKS]        [view]
# -1720945943358774381        [Peaks]        [PKS]        [view]
# -1506301473018871417        [Peaks]        [PKS]        [view]
# -1295451930882459714        [Peaks]        [PKS]        [view]
# -1077951584315524970        [Peaks]        [PKS]        [view]
# -289722276641965584         [Peaks]        [PKS]        [view]
#  357847681334138771         [Peaks]        [PKS]        [view]
#  535566393954238245         [Peaks]        [PKS]        [view]
#  580396054200165625         [Peaks]        [PKS]        [view]
#  734345270105822253         [Peaks]        [PKS]        [view]
#  2567134621152254196        [Peaks]        [PKS]        [view]
#  4056522925901197444        [Peaks]        [PKS]        [view]
#  4356738178105158401        [Peaks]        [PKS]        [view]
#  4670800706188226503        [Peaks]        [PKS]        [view]
#  4699890671745240445        [Peaks]        [PKS]        [view]
#  5231107346087398290        [Peaks]        [PKS]        [view]
#  5279940861434921501        [Peaks]        [PKS]        [view]
#  5758100849671408287        [Peaks]        [PKS]        [view]
#  6405958935940856108        [Peaks]        [PKS]        [view]
#  6494839943794824182        [Peaks]        [PKS]        [view]
#  7022198604924335400        [Peaks]        [PKS]        [view]
#  7775072887239173135        [Peaks]        [PKS]        [view]
#  8125819659820370243        [Peaks]        [PKS]        [view]
#  8133547364044521244        [Peaks]        [PKS]        [view]
#  8379254714722134375        [Peaks]        [PKS]        [view]
#  9208210556105108342        [Peaks]        [PKS]        [view]
#
# [42 rows x 189 columns]
