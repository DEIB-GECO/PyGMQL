# %% [markdown]
# ## Index
#
# 0. [Introduction](./00_Introduction.ipynb)
# 1. [A simple example](./01_A_simple_example.ipynb)
# 2. [Mixing Local and Remote processing](./02_Mixing_Local_Remote_Processing.ipynb)
# 3. [GWAS on cloud](./03_GWAS.ipynb)

# %% [markdown]
# #### Setting the JAVA_HOME environment variable (necessary only inside myBinder)
# The following instructions are only necessary in this tutorials when they are run using the myBinder interface!

# %%
import os
os.environ['JAVA_HOME'] = '/usr/'

# %% [markdown]
# # Mixing local and remote processing
#
# In this tutorial you will learn:
# 1. How to connect to a remote GMQL instance and run remote queries
# 2. How to interleave remote and local GMQL processing
# 3. How to manipulate the GDataframe data structure to plot an heatmap
# 4. How to perform a Principal Component Analysis using the GDataframe data structure
# 5. How to transform a pure Pandas Dataframe back to a GMQLDataset to perform a new query

# %% [markdown]
# ## Connecting to a remote GMQL instance
#
# PyGMQL can interact with a remote server hosting a GMQL instance and repository.
#
# In order to connect to the remote instance the user has to:
# 1. Set the IP address of the service
# 2. Login to the server
#
# It must be noticed that GMQL offers both authenticated and un-authenticated login: by default PyGMQL executes an un-authenticated login. This means that the remote instance will provide PyGMQL with limited resources and not permanent result storage. In order to login to the GMQL server as an authenticated user, one has to:
# 1. Register on the remote service by going to its IP address from the web browser
# 2. Use the `pygmql_login` tool, which is installed together with the library

# %%
import gmql as gl

gl.set_remote_address("http://genomic.elet.polimi.it/gmql-rest/")
gl.login()
# Out:
# c:\users\lucan\documents\progetti_phd\pygmql\gmql\RemoteConnection\RemoteManager.py:124: UserWarning: The authentication token for your account is expired. You need to redo the login using the pygmql tool. For now you will be logged as guest user
#   warnings.warn("The authentication token for your account is expired. "

# %% [markdown]
# From this point on, all the remote calls (explained later) will be forwarded to the GMQL service hosted at the specified address as a guest user.
#
# ## Remote execution
# With PyGMQL the user can decide if the next query (sequence of statements on GMQLDatasets ended with a materialization) will be executed locally or on the remote service.
# This can be done using the `set_mode` function. If the user sets the mode to `remote` the following will happen:
#
# 1. The local datasets that are used are uploaded to the remote service. Nothing is done to the remote datasets used in the query (if present) since they are already on the server.
# 2. A compressed representation of the query is sent to the remote service, decoded and executed
# 3. Once the execution is complete, the results are downloaded, stored and loaded into a `GDataframe`
# .

# %% [markdown]
# The following image describes the steps of remote processing with PyGMQL:
# <center><img src="./images/remote.png"></center>

# %% [markdown]
# ## The example
# We will showcase these features through a simple example.
#
# We want to understand the enrichment of histone modifications on promotorial regions of a specific set of genes (TP53, MYC, MAX, MAZ, PTEN). In particular:
#
# * The gene RefSeq annotation dataset holds the information about gene symbols and coordinates and it is stored in the remote server
# * The Chip-Seq data about histone modifications will come from ENCODE and it is as well stored in the remote system.
#
# The result of the analysis will be an heatmap $genes \times histone\_mark$ displaying the average signal value of each HM for each of the selected genes.

# %% [markdown]
# ### Finding the promotorial regions
#
# We will use as definition of promoter the region situated at $\left[gene_{start} - 2000; gene_{start} + 2000\right]$.
#
# We will perform this operation remotely.

# %%
gl.set_mode("remote")

# %% [markdown]
# We "load" the remote RefSeq dataset using the `load_from_remote` function. Since this dataset is available to all the users of the system, we will specify `public` as the ownership of the datasets. In the case in which we are loading our private datasets stored on the service, we can omit the `owner` parameter.

# %%
genes = gl.load_from_remote("HG19_ANNOTATION_REFSEQ", owner="public")

# %% [markdown]
# Now we have to:
# 1. Select only the samples from the `HG19_ANNOTATION_REFSEQ` dataset specific of genes
# 2. Select only the regions related to the genes (TP53, MYC, MAX, MAZ, PTEN)
#
# This operation can be done using the `select` function on the `gene` GMQLDataset variable.

# %%
genes = genes.select(meta_predicate=genes["annotation_type"] == 'gene')

# %% [markdown]
# To extract the promotorial regions we will use the `reg_project` (region projection) operation. In particular the following call will:
# 1. Return a dataset with only the `chr, start, stop, gene_symbol` region fields
# 2. For each gene, return the genomic position at $\left[gene_{start} - 2000; gene_{start} + 2000\right]$ taking also into account the strand of the gene.

# %%
promoters = genes.reg_project(field_list=['gene_symbol'], 
                              new_field_dict={'start': genes.start - 2000, 'stop': genes.start + 2000})

# %% [markdown]
# Since we are interested in keeping the result of this part of the query for future usage, we will materialize the result locally.

# %%
promoters = promoters.materialize("./promoters", all_load=False)

# %% [markdown]
# We can inspect the metadata of the promoters dataset.

# %%
promoters.get_metadata()

# %% [markdown]
# ### Selecting the histone marks
#
# Next we want to select the H3K27me3, H3K36me3, H3K4me1, H3K79me2, H3K9ac and H3K9me3 from the `HG19_ENCODE_BROAD_NOV_2017` dataset, also in this case stored remotely.
# As before, we will load the dataset using `load_from_remote`. The following operation is a *meta selection*, which means that the selection will be done on the metadata attributes of the dataset. The resulting dataset will have all the samples for which the metadata satisfy the specified predicate.
#
# In PyGMQL the metadata selection follows the same syntax as the Pandas Python data analysis library
# ```
# selected_dataset = dataset[dataset['metadata_attribute'] == 'value']
# ```
# Since we want to test for multiple histone marks we can use the `isin()` operator.

# %%
hms = gl.load_from_remote("HG19_ENCODE_BROAD_NOV_2017", owner="public")
hms = hms[hms['experiment_target'].isin(['H3K27me3-human', 'H3K36me3-human', 
                                         "H3K4me1-human", "H3K79me2-human", 
                                         "H3K9ac-human", "H3K9me3-human"])]

# %% [markdown]
# ### Grouping replicates
#
# The dataset resulting from the previous selection will have several duplicates for each region, due to the several biological and technical replicates offered by ENCODE. Therefore we need a way to group together the overlapping regions and to aggregate the relative signal values.
#
# This can be done using the `normal_cover` operation. In particular this function enables you to specify:
# 1. The number of minimum overlappings for a region to be kept
# 2. The maximum number of overlappings for a region to be kept
# 3. If you want to groupby the resulting samples by some metadata attribute
# 4. The aggregation function for the input region fields to be applied to the region groupings
#
# In our case we will keep all the regions (minimum overallpping = 1, maximum overlapping = "ANY") and group by the `experiment_target` metadata attribute. The signals of overlapping regions will be averaged.

# %%
hms = hms.normal_cover(1, "ANY", groupBy=['experiment_target'], 
                       new_reg_fields={'avg_signal': gl.AVG("signal")})

# %% [markdown]
# Also in this case we want to keep the resulting dataset for later processing.

# %%
hms = hms.materialize("./hms", all_load=False)

# %% [markdown]
# ### Mapping the histone marks signal to the promotorial regions
#
# Now that we have our set of gene promoters and our set of histone marks, we want to map the signal of the latter to the regions of the former. We can do that using the `map` operation. In particular, since on a promotorial region can be mapped multiple HMs, we will aggregate the signal by averaging it.
#
# We decide to perform the following operations on the local machine.

# %%
gl.set_mode("local")

# %%
mapping = promoters.map(hms, refName='prom', 
                        expName="hm", 
                        new_reg_fields={'avg_signal': gl.AVG("avg_signal")})

# %% [markdown]
# We finally materialize the result and load it in a GDataframe.

# %%
mapping = mapping.materialize("./mapping")

# %%
mapping.regs
# Out:
#                chr      start       stop strand   gene_symbol  count_prom_hm  \
# id_sample
# S_00000.gdm   chr1   93979906   93983906      -     TRNAC-GCA            0.0
# S_00000.gdm   chr5   72249807   72253807      +         FCHO2            1.0
# S_00000.gdm   chrX   77581188   77585188      -       CYSLTR1            0.0
# S_00000.gdm  chr16   60391697   60395697      -     LOC729159            0.0
# S_00000.gdm   chr3  123849775  123853775      +       MIR5002            0.0
# S_00000.gdm   chr4  102160029  102164029      -       MIR8066            2.0
# S_00000.gdm   chr7  102790772  102794772      -     RPL23AP95            1.0
# S_00000.gdm   chr6   26381323   26385323      +        BTN2A2            1.0
# S_00000.gdm   chr6   30329888   30333888      -      UBQLN1P1            0.0
# S_00000.gdm   chr6    4250521    4254521      -          TAP1            0.0
# S_00000.gdm  chr16   87968112   87972112      -          CA5A            0.0
# S_00000.gdm   chr6   29874422   29878422      -       MCCD1P1            0.0
# S_00000.gdm   chr6    4097716    4101716      -         PSMB8            0.0
# S_00000.gdm   chr3  148845370  148849370      +          HPS3            1.0
# S_00000.gdm  chr14   23787396   23791396      +        PABPN1            1.0
# S_00000.gdm   chrX   74419304   74423304      +       BUD31P2            0.0
# S_00000.gdm   chr6   63919351   63923351      +        FKBP1C            0.0
# S_00000.gdm   chr5  124142924  124146924      -       RPL28P3            0.0
# S_00000.gdm   chrX   39645213   39649213      -       GAPDHP1            0.0
# S_00000.gdm  chr16    5664251    5668251      -     LINC01570            0.0
# S_00000.gdm  chr19   18449396   18453396      +        PGPEP1            1.0
# S_00000.gdm   chr2  170588355  170592355      +        KLHL23            1.0
# S_00000.gdm  chr15   32892321   32896321      +     RN7SL286P            0.0
# S_00000.gdm   chr6   56706783   56710783      +  LOC101930010            1.0
# S_00000.gdm   chr9  133452881  133456881      -  LOC100272217            1.0
# S_00000.gdm   chr7   39871392   39875392      -  LOC100422519            1.0
# S_00000.gdm   chrX  125951746  125955746      +         PRR32            0.0
# S_00000.gdm   chr6    2844307    2848307      -          NCR3            1.0
# S_00000.gdm   chr8  110344551  110348551      +          ENY2            1.0
# S_00000.gdm  chr17   46231873   46235873      -       MIR1203            0.0
# ...            ...        ...        ...    ...           ...            ...
# S_00005.gdm   chr7   93518205   93522205      +  LOC105375401            1.0
# S_00005.gdm   chr5  177300261  177304261      +     LOC728554            0.0
# S_00005.gdm   chr6   73675476   73679476      -       MIR4282            0.0
# S_00005.gdm   chr3    8809300    8813300      -          OXTR            1.0
# S_00005.gdm   chr3   61726811   61730811      -      RPL10AP6            1.0
# S_00005.gdm   chr1   27139312   27143312      +     RN7SL165P            0.0
# S_00005.gdm   chrX  101852095  101856095      +        ARMCX5            1.0
# S_00005.gdm   chr1   25596976   25600976      +           RHD            0.0
# S_00005.gdm  chr17   15606407   15610407      -       UBE2SP1            1.0
# S_00005.gdm  chr13   45561664   45565664      +       GPALPP1            1.0
# S_00005.gdm  chr13   28525662   28529662      +     LINC00543            0.0
# S_00005.gdm   chr7  121942565  121946565      -         FEZF1            1.0
# S_00005.gdm   chr2   62083277   62087277      +  LOC100533678            1.0
# S_00005.gdm   chr5  140732591  140736591      +       PCDHGA4            0.0
# S_00005.gdm  chr14   65005185   65009185      +         HSPA2            1.0
# S_00005.gdm   chrY    9003636    9007636      -         CDY3P            0.0
# S_00005.gdm   chr6    3338456    3342456      -          NEU1            1.0
# S_00005.gdm   chrY   19947408   19951408      -        ELOCP6            0.0
# S_00005.gdm   chr3  134202574  134206574      +         CEP63            1.0
# S_00005.gdm   chr1  149820627  149824627      +    HIST2H2AA4            1.0
# S_00005.gdm  chr14   23477410   23481410      -      C14orf93            1.0
# S_00005.gdm  chr19   57740376   57744376      +         AURKC            0.0
# S_00005.gdm   chr1   89639723   89643723      -          GBP7            0.0
# S_00005.gdm   chr6      85747      89747      +       TRNAA36            0.0
# S_00005.gdm   chr3  180585966  180589966      -  LOC101928882            0.0
# S_00005.gdm   chr3     349002     353002      -        RPS8P6            0.0
# S_00005.gdm  chr18   67135166   67139166      +  LOC105372179            0.0
# S_00005.gdm  chr20   25175528   25179528      -  LOC101926889            1.0
# S_00005.gdm  chr21    9763959    9767959      +   ANKRD20A16P            0.0
# S_00005.gdm  chr20   35167886   35171886      +          MYL9            1.0
#
#              avg_signal
# id_sample
# S_00000.gdm         NaN
# S_00000.gdm   29.234975
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm    7.218334
# S_00000.gdm   27.210077
# S_00000.gdm   15.446432
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm   23.499031
# S_00000.gdm   31.190553
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm         NaN
# S_00000.gdm    4.753326
# S_00000.gdm   14.543422
# S_00000.gdm         NaN
# S_00000.gdm   10.407146
# S_00000.gdm   45.088444
# S_00000.gdm    7.491049
# S_00000.gdm         NaN
# S_00000.gdm    5.577254
# S_00000.gdm   25.643275
# S_00000.gdm         NaN
# ...                 ...
# S_00005.gdm    5.423960
# S_00005.gdm         NaN
# S_00005.gdm         NaN
# S_00005.gdm    6.440402
# S_00005.gdm    3.463864
# S_00005.gdm         NaN
# S_00005.gdm    6.162037
# S_00005.gdm         NaN
# S_00005.gdm    5.552889
# S_00005.gdm   11.587390
# S_00005.gdm         NaN
# S_00005.gdm    6.332943
# S_00005.gdm    3.542561
# S_00005.gdm         NaN
# S_00005.gdm   14.151213
# S_00005.gdm         NaN
# S_00005.gdm    7.160337
# S_00005.gdm         NaN
# S_00005.gdm    6.702714
# S_00005.gdm    7.305929
# S_00005.gdm    9.369072
# S_00005.gdm         NaN
# S_00005.gdm         NaN
# S_00005.gdm         NaN
# S_00005.gdm         NaN
# S_00005.gdm         NaN
# S_00005.gdm         NaN
# S_00005.gdm    1.836100
# S_00005.gdm         NaN
# S_00005.gdm   10.343712
#
# [282180 rows x 7 columns]

# %%
mapping.meta
# Out:
#             hm.antibody_accession    hm.assay hm.assembly  \
# id_sample
# S_00000.gdm         [ENCAB000ANK]  [ChIP-seq]      [hg19]
# S_00001.gdm         [ENCAB000ANX]  [ChIP-seq]      [hg19]
# S_00002.gdm         [ENCAB000ANB]  [ChIP-seq]      [hg19]
# S_00003.gdm         [ENCAB000ADW]  [ChIP-seq]      [hg19]
# S_00004.gdm         [ENCAB000ANH]  [ChIP-seq]      [hg19]
# S_00005.gdm         [ENCAB000ADU]  [ChIP-seq]      [hg19]
#
#                                                 hm.audit_error  \
# id_sample
# S_00000.gdm                                                 []
# S_00001.gdm                                                 []
# S_00002.gdm                                                 []
# S_00003.gdm                         [extremely low read depth]
# S_00004.gdm                                                 []
# S_00005.gdm  [control extremely low read depth, extremely l...
#
#                                       hm.audit_internal_action  \
# id_sample
# S_00000.gdm  [biological replicates with identical biosampl...
# S_00001.gdm  [biological replicates with identical biosampl...
# S_00002.gdm  [missing derived_from, missing unfiltered alig...
# S_00003.gdm  [biological replicates with identical biosampl...
# S_00004.gdm  [missing derived_from, missing unfiltered alig...
# S_00005.gdm  [biological replicates with identical biosampl...
#
#                                         hm.audit_not_compliant  \
# id_sample
# S_00000.gdm  [insufficient read depth, poor library complex...
# S_00001.gdm  [control insufficient read depth, insufficient...
# S_00002.gdm  [control insufficient read depth, insufficient...
# S_00003.gdm  [control insufficient read depth, insufficient...
# S_00004.gdm  [control insufficient read depth, insufficient...
# S_00005.gdm  [control insufficient read depth, insufficient...
#
#                                               hm.audit_warning  \
# id_sample
# S_00000.gdm  [low read length, mild to moderate bottlenecking]
# S_00001.gdm  [inconsistent platforms, low read depth, low r...
# S_00002.gdm  [inconsistent platforms, low read length, mild...
# S_00003.gdm  [low read length, mild to moderate bottlenecking]
# S_00004.gdm          [inconsistent platforms, low read length]
# S_00005.gdm  [inconsistent platforms, low read length, mild...
#
#             hm.biological_replicate_s_             hm.biosample_age  \
# id_sample
# S_00000.gdm                         []                    [58 year]
# S_00001.gdm                         []           [53 year, unknown]
# S_00002.gdm                     [1, 2]  [31 year, 53 year, unknown]
# S_00003.gdm                         []           [58 year, unknown]
# S_00004.gdm                         []                    [53 year]
# S_00005.gdm                         []  [31 year, 53 year, unknown]
#
#                hm.biosample_life_stage         ...           \
# id_sample                                      ...
# S_00000.gdm                    [adult]         ...
# S_00001.gdm         [adult, embryonic]         ...
# S_00002.gdm         [adult, embryonic]         ...
# S_00003.gdm  [adult, newborn, unknown]         ...
# S_00004.gdm                    [adult]         ...
# S_00005.gdm  [adult, newborn, unknown]         ...
#
#                                   prom.data_format_description  \
# id_sample
# S_00000.gdm  [http://biomirror.aarnet.edu.au/biomirror/ncbi...
# S_00001.gdm  [http://biomirror.aarnet.edu.au/biomirror/ncbi...
# S_00002.gdm  [http://biomirror.aarnet.edu.au/biomirror/ncbi...
# S_00003.gdm  [http://biomirror.aarnet.edu.au/biomirror/ncbi...
# S_00004.gdm  [http://biomirror.aarnet.edu.au/biomirror/ncbi...
# S_00005.gdm  [http://biomirror.aarnet.edu.au/biomirror/ncbi...
#
#                                             prom.download_link  \
# id_sample
# S_00000.gdm  [ftp://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/a...
# S_00001.gdm  [ftp://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/a...
# S_00002.gdm  [ftp://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/a...
# S_00003.gdm  [ftp://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/a...
# S_00004.gdm  [ftp://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/a...
# S_00005.gdm  [ftp://ftp.ncbi.nlm.nih.gov/refseq/H_sapiens/a...
#
#                                    prom.full_name prom.genome_build  \
# id_sample
# S_00000.gdm  [RefSeq Reference Genome Annotation]      [GRCh37.p13]
# S_00001.gdm  [RefSeq Reference Genome Annotation]      [GRCh37.p13]
# S_00002.gdm  [RefSeq Reference Genome Annotation]      [GRCh37.p13]
# S_00003.gdm  [RefSeq Reference Genome Annotation]      [GRCh37.p13]
# S_00004.gdm  [RefSeq Reference Genome Annotation]      [GRCh37.p13]
# S_00005.gdm  [RefSeq Reference Genome Annotation]      [GRCh37.p13]
#
#             prom.genome_build_accession prom.original_format  \
# id_sample
# S_00000.gdm          [GCF_000001405.25]                [gff]
# S_00001.gdm          [GCF_000001405.25]                [gff]
# S_00002.gdm          [GCF_000001405.25]                [gff]
# S_00003.gdm          [GCF_000001405.25]                [gff]
# S_00004.gdm          [GCF_000001405.25]                [gff]
# S_00005.gdm          [GCF_000001405.25]                [gff]
#
#                                              prom.original_url prom.provider  \
# id_sample
# S_00000.gdm  [https://www.ncbi.nlm.nih.gov/projects/genome/...      [RefSeq]
# S_00001.gdm  [https://www.ncbi.nlm.nih.gov/projects/genome/...      [RefSeq]
# S_00002.gdm  [https://www.ncbi.nlm.nih.gov/projects/genome/...      [RefSeq]
# S_00003.gdm  [https://www.ncbi.nlm.nih.gov/projects/genome/...      [RefSeq]
# S_00004.gdm  [https://www.ncbi.nlm.nih.gov/projects/genome/...      [RefSeq]
# S_00005.gdm  [https://www.ncbi.nlm.nih.gov/projects/genome/...      [RefSeq]
#
#             prom.release_date prom.release_version
# id_sample
# S_00000.gdm      [2013-06-28]                 [13]
# S_00001.gdm      [2013-06-28]                 [13]
# S_00002.gdm      [2013-06-28]                 [13]
# S_00003.gdm      [2013-06-28]                 [13]
# S_00004.gdm      [2013-06-28]                 [13]
# S_00005.gdm      [2013-06-28]                 [13]
#
# [6 rows x 45 columns]

# %% [markdown]
# ### Visualizing the HM signal heatmap on the gene promoters
#
# Finally we visualize the heatmap (in the form of clusters) with the assistance of the Seaborn visualization package.
# In order to visualize the data we have to transform the GDataframe data structure in the `mapping` variable in a matricial form where we have $genes$ on the rows and $histone\_marks$ on the columns. This can be done with the `to_matrix` function offered by the GDataframe.
#
# The `to_matrix` method is particularly versatile since it enables the user to project region and metadata at the same time. For example, in our case the information about the histone modification name is stored as a metadata attribute `hm.experiment_target` while we want to use the `avg_signal` region field as matrix value. The `to_matrix` methods therefore enable us to aggregate the information of both regions and metadata in a single structure.
#
# Underneeth this method leverages on the `pivot_table` Pandas function and can accept all its parameter together with its specific ones.

# %%
# !pip install seaborn
# !pip install scikit-learn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure()
sns.clustermap(mapping.to_matrix(index_regs=['gene_symbol'], 
                  columns_meta=['hm.experiment_target'], 
                  values_regs=['avg_signal'], fill_value=0, dropna=False).sample(100), yticklabels=False, )
plt.show()

# %% [markdown]
# ### Performing Principal Component Analysis

# %%
from sklearn.decomposition import PCA
import pandas as pd

# %%
pca = PCA(n_components=2)

# %%
promoter_region_VS_hm = mapping.to_matrix(index_regs=['chr', 'start', 'stop', 'gene_symbol'], 
                                                 columns_meta=['hm.experiment_target'], 
                                                 values_regs=['avg_signal'], fill_value=0)

components = pca.fit_transform(promoter_region_VS_hm.values)

# %%
PCA_regions = pd.DataFrame(index=promoter_region_VS_hm.index, columns=['1st_component', '2nd_component'], data=components).reset_index()

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(data=PCA_regions, x='1st_component', y='2nd_component', s=100)
plt.show()
